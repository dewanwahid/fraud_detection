# %% [markdown]
# # Script 01: Identifying Fraud Risk Accounts

# %%
## 
import pandas as pd
import numpy as np
from datetime import date

from scipy import stats
get_ipython().magic(u'config IPCompleter.greedy=True')

# %%
## Testing AWS Connectivity
from contextlib import closing


import psycopg2
import simplejson
import sys
reload(sys)
sys.setdefaultencoding('utf8')

DEFAULT_DB = 'data_depot'
DEFAULT_HOST = 'freshbooks-data.c8exzn6geij3.us-east-1.redshift.amazonaws.com'
DEFAULT_PORT = 5439


class PsycopgConnector:
    '''
    A database connector that uses Psycopg to connect to Redshift.

    How to play:

        psy_conn = PsycopgConnector(username, password)
        df = psy_conn.run_query(sql=sql, return_data=True)

    NOTE: This class commits queries to redshift if return_data=False.
    This means INSERT, DROP, TRUNCATE, etc. all work against the DB.
    '''

    def __init__(
        self,
        username=None,
        password=None,
        db=DEFAULT_DB,
        host=DEFAULT_HOST,
        port=DEFAULT_PORT,
    ):

        self.db = DEFAULT_DB
        self.host = DEFAULT_HOST
        self.port = DEFAULT_PORT

        self.username = username
        self.password = password

    def _get_connection(self):

        self.conn = psycopg2.connect(
            dbname=self.db,
            user=self.username,
            password=self.password,
            host=self.host,
            port=self.port
        )

        return self.conn

    def run_query(self, sql, return_data=False):

        with closing(self._get_connection()) as conn:
            with conn, conn.cursor() as cur:
                if return_data:
                    return pd.read_sql(sql=sql, con=conn)
                else:
                    cur.execute(sql)
                    

# Read the Redshift's credentials file 
with open("redshift_creds.json.nogit") as fh:
    creds = simplejson.loads(fh.read())
    
username = creds.get("user_name")
password = creds.get("password")

pig = PsycopgConnector(username, password)

# Testing connection
sql_test = '''SELECT * FROM report_systems LIMIT 5'''
df_test = pig.run_query(sql_test, return_data=True)

# %%
df_test
# Out:
#    systemid  business_id  admin_identity_id  \
# 0        76          NaN                NaN
# 1      2865          NaN                NaN
# 2      3050          NaN                NaN
# 3      5490      61687.0            90905.0
# 4      5900          NaN                NaN
#
#                              subdomain  is_freshbooks_account_active  \
# 0       https://rimages.freshbooks.com                             1
# 1  https://mooredesigns.freshbooks.com                             0
# 2       https://thrifty.freshbooks.com                             1
# 3         https://jonom.freshbooks.com                             1
# 4       https://nrgomes.freshbooks.com                             1
#
#    is_modern most_recent_migrated_to_smux_at  is_contractor currency_code  \
# 0          0                            None              0           EUR
# 1          0                            None              0           USD
# 2          0                            None              0           USD
# 3          1                      2016-10-11              0           CAD
# 4          0                            None              0           EUR
#
#         timezone  ...  staff_count staff_deleted_count contractor_count  \
# 0     US/Eastern  ...            0                   0                0
# 1    US/Mountain  ...            1                   0                0
# 2     US/Eastern  ...            0                   0                0
# 3     US/Pacific  ...            0                   0                0
# 4  Europe/London  ...            1                   0                0
#
#   contractor_deleted_count user_contact_count enabled_gateway_count  \
# 0                        0                 18                     1
# 1                        0                 86                     1
# 2                        0                  3                     2
# 3                        0                  0                     1
# 4                        0                  0                     0
#
#   google_sso_first_linked_date google_sso_most_recent_linked_date  \
# 0                         None                               None
# 1                         None                               None
# 2                         None                               None
# 3                         None                               None
# 4                         None                               None
#
#   google_sso_first_removal_date google_sso_most_recent_removal_date
# 0                          None                                None
# 1                          None                                None
# 2                          None                                None
# 3                          None                                None
# 4                          None                                None
#
# [5 rows x 141 columns]

# %% [markdown]
# ## Number of Fraud Risk Accounts (N)
#
# Please enter the nubmer **(N)** of Fraud Risk Accounts that you want to check today.

# %%
#------------------------------------------------------------
# PLEASE READ AND ANSWER THIS QUESTION
#
# Question: How many accounts you want to check today?
# Answer: Number of Accounts: N
#-----------------------------------------------------------
N = 25
#-------------------------------------------------------------

# %% [markdown]
# ## Computing Fraud Risk Score (FRS)
#
# This following script will query new account (if already not labeled) those are signed-up within last 91 days (from today), and compute the corresponding **Fraud Risk Score (FRS)**.

# %%
## Pull new user accounts and compute Fraud Risk Score (FRS)
# %run ./fraud_risk_score_computing.ipynb

# %%
## Import new user accounts and corresponding Fraud Risk Score (FRS)
path = "/Users/dwahid/Documents/GitHub/fraud_detection/data/fraud_risk_acc_to_be_labeled_all_features/"

## Without date
# file_name = "new_fraud_risk_acc_tbl_all_features"
# data = path + file_name + ".tsv"

## With date
file_name = "new_fraud_risk_acc_tbl_all_features_"
today = str(date.today())
data = path + file_name + today + ".tsv"

df_fra_all_features = pd.read_csv(data, sep="\t")   # FRA - Fraud Risk Accounts

# %%
df_fra_all_features.tail()
# Out:
#        activateexpense  activateotherincome  activatepayment  \
# 55160              0.0                  0.0              0.0
# 55161              0.0                  0.0              0.0
# 55162              0.0                  0.0              0.0
# 55163              0.0                  0.0              0.0
# 55164              0.0                  0.0              0.0
#
#                                admin_email  admindeactivation  \
# 55160                  dwahinya@icloud.com                0.0
# 55161  aya.1919113@stemgharbiya.moe.edu.eg                0.0
# 55162                  ofaydavis@yahoo.com                0.0
# 55163               gautamsun784@gmail.com                0.0
# 55164               arielsoto379@gmail.com                0.0
#
#        adminonlinepaymentattempt  adminpayinvoiceonlineinvoice  \
# 55160                          0                             0
# 55161                          0                             0
# 55162                          0                             0
# 55163                          0                             0
# 55164                          0                             0
#
#        adminpayinvoiceonlinelistview  archiveclient  archiveexpense  ...  \
# 55160                            0.0            0.0             0.0  ...
# 55161                            0.0            0.0             0.0  ...
# 55162                            0.0            0.0             0.0  ...
# 55163                            0.0            0.0             0.0  ...
# 55164                            0.0            0.0             0.0  ...
#
#        updatecontractor  updatecreditnote  updateestimate  updateexpense  \
# 55160               0.0                 0             0.0            0.0
# 55161               0.0                 0             0.0            0.0
# 55162               0.0                 0             0.0            0.0
# 55163               0.0                 0             0.0            0.0
# 55164               0.0                 0             0.0            0.0
#
#        updateinvoicesample  updateitem  updateservice  fraud_risk_score  \
# 55160                  1.0         0.0            0.0               0.0
# 55161                  1.0         0.0            0.0               0.0
# 55162                  0.0         0.0            0.0               0.0
# 55163                  0.0         0.0            0.0               0.0
# 55164                  0.0         0.0            0.0               0.0
#
#        fraud_label  support_note
# 55160          TBL           NaN
# 55161          TBL           NaN
# 55162          TBL           NaN
# 55163          TBL           NaN
# 55164          TBL           NaN
#
# [5 rows x 97 columns]

# %%
df_fra_all_features.shape
# Out:
# (55165, 97)

# %% [markdown]
# ## Return Top N Fraud Risk Accounts for Support Labeling
# It will return a list of top N FRA accounts for support labeleing.

# %%
## Top N accounts for support team reporting
df_fra_topN_all_features = df_fra_all_features.head(N)

## Selecting colums for support team reporting
df_fra_topN_for_support = df_fra_topN_all_features[['systemid', 'admin_email', 'signup_date', 
                                                   'effective_date', 'days_on_platform', 'fraud_label', 'support_note']]

## Path and file name for user accounts for need to be labeled by support team
path = "/Users/dwahid/Documents/GitHub/fraud_detection/data/fraud_risk_acc_to_be_labeled_for_support/"

## Without date
# file_name = "new_fraud_risk_acc_tbl_for_support"
# path_fra_topN_for_support = path + file_name + ".csv"

## With date 
file_name = "new_fraud_risk_acc_tbl_for_support_"
today = str(date.today())
path_fra_topN_for_support = path + file_name + today + ".csv"

## Save the user accounts for need to be labeled by support team
df_fra_topN_for_support.to_csv(path_fra_topN_for_support, sep=",", index=False)

# %%
df_fra_topN_for_support.head(25)
# Out:
#     systemid                       admin_email signup_date effective_date  \
# 0    5423977           jkpttreasures@gmail.com  2020-06-24     2020-07-06
# 1    5420121             abel@foliocomunic.com  2020-06-23     2020-07-06
# 2    5377715              lui.nathan@gmail.com  2020-06-12     2020-07-06
# 3    5417697   saajith.samoon@themugshotlk.com  2020-06-23     2020-07-06
# 4    5434377            ben@bayintegration.com  2020-06-26     2020-07-06
# 5    5433889               katerbugs@gmail.com  2020-06-26     2020-07-06
# 6    5341301            pauladlynn29@gmail.com  2020-06-03     2020-07-06
# 7    5433763        brandon.cedarmfg@gmail.com  2020-06-26     2020-07-06
# 8    5435493      anthonyholroyd1991@gmail.com  2020-06-27     2020-07-06
# 9    5410469            rishitaadani@gmail.com  2020-06-20     2020-07-06
# 10   5421279  bluegrassdistributorky@gmail.com  2020-06-23     2020-07-06
# 11   5435801         gracefullyglam@icloud.com  2020-06-27     2020-07-06
# 12   5421173            chrissykay88@gmail.com  2020-06-23     2020-07-06
# 13   5440889    artifexcustomgallery@yahoo.com  2020-06-28     2020-07-06
# 14   5432393           rosamariamp@hotmail.com  2020-06-26     2020-07-06
# 15   5371927        branden@coastalpremier.com  2020-06-10     2020-07-06
# 16   5383497           stevehendo148@gmail.com  2020-06-14     2020-07-06
# 17   5420373       trinitygeneral651@gmail.com  2020-06-23     2020-07-06
# 18   5423125           techzone.ae@outlook.com  2020-06-24     2020-07-06
# 19   5362121             dzul@lovebites.com.sg  2020-06-08     2020-07-06
# 20   5430289   insomniacaudioforever@gmail.com  2020-06-25     2020-07-06
# 21   5427857               jbrown@cognetif.com  2020-06-25     2020-07-06
# 22   5368537      contact.redlotusbw@gmail.com  2020-06-09     2020-07-06
# 23   5367337            victoria@zontgroup.com  2020-06-09     2020-07-06
# 24   5431425        graememackinnon3@gmail.com  2020-06-26     2020-07-06
#
#     days_on_platform fraud_label  support_note
# 0                 12         TBL           NaN
# 1                 13         TBL           NaN
# 2                 24         TBL           NaN
# 3                 13         TBL           NaN
# 4                 10         TBL           NaN
# 5                 10         TBL           NaN
# 6                 33         TBL           NaN
# 7                 10         TBL           NaN
# 8                  9         TBL           NaN
# 9                 16         TBL           NaN
# 10                13         TBL           NaN
# 11                 9         TBL           NaN
# 12                13         TBL           NaN
# 13                 8         TBL           NaN
# 14                10         TBL           NaN
# 15                26         TBL           NaN
# 16                22         TBL           NaN
# 17                13         TBL           NaN
# 18                12         TBL           NaN
# 19                28         TBL           NaN
# 20                11         TBL           NaN
# 21                11         TBL           NaN
# 22                27         TBL           NaN
# 23                27         TBL           NaN
# 24                10         TBL           NaN

# %%
df_fra_topN_for_support.shape
# Out:
# (25, 7)

# %%
"You data file for Support labeling is ready"
# Out:
# 'You data file for Support labeling is ready'
