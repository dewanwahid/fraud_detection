# %% [markdown]
# # Fraud Detection Day 49 Model: Gaussian Mixture Model (GMM)

# %%
import pandas as pd
import numpy as np

import seaborn as sns
sns.set(color_codes=True)

import matplotlib.pyplot as plt
plt.style.use('ggplot')
# %matplotlib inline

from scipy import stats
get_ipython().magic(u'config IPCompleter.greedy=True')

from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn import mixture
import pickle

# %% [markdown]
# ## 1. Import and Filter Features Data for Day 49
#
# ### 1.1 Import day 49 final features data

# %%
# Import day 07 features data 
df = pd.read_csv(
    "/Users/dwahid/Documents/GitHub/fraud_detection/data/training_data/final_features_day_49_no_fbtest_onlyimp_noinactive.tsv", sep="\t")

# %%
# checking dataframe
# df.tail()
df.shape
# list(df)
# Out:
# (438299, 105)

# %%
# Editing dataframe colume names
df.columns = [
    col.replace('-', '').replace('/', '')
    for col in df.columns
]

# %%
## Sorting column in the dataframe
df = df.reindex(sorted(df.columns), axis=1)

# %%
## Get the column index
col_names = list(df)
L = len(col_names)

for i in range(0, L):
    print i, col_names[i]
# Out:
# 0 activateestimate
# 1 activateexpense
# 2 activateotherincome
# 3 activatepayment
# 4 activateproject
# 5 activaterecurringprofile
# 6 activatestaff
# 7 admindeactivation
# 8 adminonlinepaymentattempt
# 9 adminpayinvoiceonlineinvoice
# 10 adminpayinvoiceonlinelistview
# 11 archiveclient
# 12 archiveexpense
# 13 archiveotherincome
# 14 archiveproject
# 15 archivetask
# 16 autobillpayment
# 17 avg_wc_address_day_49
# 18 avg_wc_description_day_49
# 19 avg_wc_notes_day_49
# 20 avg_wc_terms_day_49
# 21 banktransferdisabled
# 22 banktransferenabled
# 23 bulkimportclientscomplete
# 24 bulkimportitemsandservicescomplete
# 25 client_count_day_49
# 26 clientimportcsvsucceeded
# 27 clientlimitupgradenudge
# 28 createbankaccount
# 29 createbanktransaction
# 30 createbanktransfer
# 31 createcategory
# 32 createcontact
# 33 createcontractor
# 34 createcreditnote
# 35 createdexpense
# 36 createestimate
# 37 createexpense
# 38 createitem
# 39 createotherincome
# 40 createreceipt
# 41 createservice
# 42 creditcardclientaccessgranted
# 43 creditcardsystemaccessrevoked
# 44 customemailsignature
# 45 declinedonlinepaymentnotification
# 46 deletebusinessaccountant
# 47 deletebusinesspartner
# 48 deletecollaborator
# 49 deletecreditnote
# 50 deleteestimate
# 51 deleteexpense
# 52 deletehours
# 53 deleteinvoice
# 54 deleteitem
# 55 deleteotherincome
# 56 deleteproject
# 57 deleterecurringexpense
# 58 deleteretainerprofile
# 59 deletestaff
# 60 deletesystemgateway
# 61 deletetimeentry
# 62 deleteuser
# 63 disconnectbankaccount
# 64 disconnectpaymentgateway
# 65 dualstripepaypalgatewayexperienceinvoicepopupclick
# 66 emailcreditnote
# 67 emailestimate
# 68 emailestimatetoself
# 69 emailinvoice
# 70 emailinvoicesample
# 71 emailreport
# 72 emailsent
# 73 enableautobilling
# 74 enablepaymentgateway
# 75 expenseimportsucceeded
# 76 exportjournalentries
# 77 fbpayenabled
# 78 fbpayfirstinvoicesent
# 79 fbpayupdatedacceptedcreditcards
# 80 fbpayuserconnectedbank
# 81 generateinvoicefromrecurringprofile
# 82 hitpaywallclientlimit
# 83 hourslogged
# 84 identitycompletedonboarding
# 85 invoice_count_day_49
# 86 is_freshbooks_account_active
# 87 is_paying
# 88 is_sales_managed
# 89 login
# 90 stripepaymentsuccessful
# 91 successfulonlinepayment
# 92 surveyquestionanswered
# 93 systemid
# 94 updatebusiness
# 95 updatecategory
# 96 updateclient
# 97 updatecompanyprofile
# 98 updatecontractor
# 99 updatecreditnote
# 100 updateestimate
# 101 updateexpense
# 102 updateinvoicesample
# 103 updateitem
# 104 updateservice

# %% [markdown]
# ## 2. Cleaning Data for GMM Clustering
# ### 2.1 Drop row with missing 'systemid'

# %%
# Finding the features columns varinaces
df = df.drop(columns=[
                                 'activateestimate',
                                 'activateproject',
                                 'activaterecurringprofile',
                                 'activatestaff',
                                 'banktransferdisabled',
                                 'banktransferenabled',
                                 'bulkimportitemsandservicescomplete',
                                 'creditcardsystemaccessrevoked',
                                 'deletetimeentry',
                                 'deleterecurringexpense',
                                 'deleteretainerprofile',
                                 'deletebusinessaccountant',
                                 'deletesystemgateway',
                                 'exportjournalentries',
                                 'generateinvoicefromrecurringprofile',
                                 'fbpayuserconnectedbank' , 'is_sales_managed'
                                ], axis=1)

# %%
## Get the column index
col_names = list(df)
L = len(col_names)

for i in range(0, L):
    print i, col_names[i]
# Out:
# 0 activateexpense
# 1 activateotherincome
# 2 activatepayment
# 3 admindeactivation
# 4 adminonlinepaymentattempt
# 5 adminpayinvoiceonlineinvoice
# 6 adminpayinvoiceonlinelistview
# 7 archiveclient
# 8 archiveexpense
# 9 archiveotherincome
# 10 archiveproject
# 11 archivetask
# 12 autobillpayment
# 13 avg_wc_address_day_49
# 14 avg_wc_description_day_49
# 15 avg_wc_notes_day_49
# 16 avg_wc_terms_day_49
# 17 bulkimportclientscomplete
# 18 client_count_day_49
# 19 clientimportcsvsucceeded
# 20 clientlimitupgradenudge
# 21 createbankaccount
# 22 createbanktransaction
# 23 createbanktransfer
# 24 createcategory
# 25 createcontact
# 26 createcontractor
# 27 createcreditnote
# 28 createdexpense
# 29 createestimate
# 30 createexpense
# 31 createitem
# 32 createotherincome
# 33 createreceipt
# 34 createservice
# 35 creditcardclientaccessgranted
# 36 customemailsignature
# 37 declinedonlinepaymentnotification
# 38 deletebusinesspartner
# 39 deletecollaborator
# 40 deletecreditnote
# 41 deleteestimate
# 42 deleteexpense
# 43 deletehours
# 44 deleteinvoice
# 45 deleteitem
# 46 deleteotherincome
# 47 deleteproject
# 48 deletestaff
# 49 deleteuser
# 50 disconnectbankaccount
# 51 disconnectpaymentgateway
# 52 dualstripepaypalgatewayexperienceinvoicepopupclick
# 53 emailcreditnote
# 54 emailestimate
# 55 emailestimatetoself
# 56 emailinvoice
# 57 emailinvoicesample
# 58 emailreport
# 59 emailsent
# 60 enableautobilling
# 61 enablepaymentgateway
# 62 expenseimportsucceeded
# 63 fbpayenabled
# 64 fbpayfirstinvoicesent
# 65 fbpayupdatedacceptedcreditcards
# 66 hitpaywallclientlimit
# 67 hourslogged
# 68 identitycompletedonboarding
# 69 invoice_count_day_49
# 70 is_freshbooks_account_active
# 71 is_paying
# 72 login
# 73 stripepaymentsuccessful
# 74 successfulonlinepayment
# 75 surveyquestionanswered
# 76 systemid
# 77 updatebusiness
# 78 updatecategory
# 79 updateclient
# 80 updatecompanyprofile
# 81 updatecontractor
# 82 updatecreditnote
# 83 updateestimate
# 84 updateexpense
# 85 updateinvoicesample
# 86 updateitem
# 87 updateservice

# %%
# Keep a copy of the original dataframe
df_orig = df.copy()

# Rearranging Columns (alphabatically)
df = df.sort_index(axis=1)

# %% [markdown]
# ### 2.3 Feature column normalization (model)

# %%
# Normalized all features columns except the 'systemid'
column_names_to_not_normalize = ['systemid']
column_names_to_normalize = [x for x in list(df) if x not in column_names_to_not_normalize ]

# Min-Max standarization model
min_max_scaler = MinMaxScaler()

# Fit and transfrom the data
x = df[column_names_to_normalize].values
x_scaled = min_max_scaler.fit_transform(x)
df_temp = pd.DataFrame(x_scaled, columns=column_names_to_normalize, index = df.index)
df[column_names_to_normalize] = df_temp

# %%
# Save the standarization model: min-max scalar
filename_minmax_scaler = '/Users/dwahid/Documents/GitHub/fraud_detection/src/saved_models/minmax_scaler_gmm_day_49.sav'
pickle.dump(min_max_scaler, open(filename_minmax_scaler, 'wb'))

# %%
# Remove any column with 'Nan'
df.fillna(0, inplace=True)

# Drop the 'systemid' 
df_nosystemid = df.drop(['systemid'], axis=1)

# %%
df_nosystemid.describe()
# Out:
#        activateexpense  activateotherincome  activatepayment  \
# count    438299.000000        438299.000000    438299.000000
# mean          0.000027             0.000009         0.000013
# std           0.002926             0.002122         0.001870
# min           0.000000             0.000000         0.000000
# 25%           0.000000             0.000000         0.000000
# 50%           0.000000             0.000000         0.000000
# 75%           0.000000             0.000000         0.000000
# max           1.000000             1.000000         1.000000
#
#        admindeactivation  adminonlinepaymentattempt  \
# count      438299.000000              438299.000000
# mean            0.000253                   0.000005
# std             0.011351                   0.001756
# min             0.000000                   0.000000
# 25%             0.000000                   0.000000
# 50%             0.000000                   0.000000
# 75%             0.000000                   0.000000
# max             1.000000                   1.000000
#
#        adminpayinvoiceonlineinvoice  adminpayinvoiceonlinelistview  \
# count                 438299.000000                  438299.000000
# mean                       0.000004                       0.000006
# std                        0.001571                       0.001794
# min                        0.000000                       0.000000
# 25%                        0.000000                       0.000000
# 50%                        0.000000                       0.000000
# 75%                        0.000000                       0.000000
# max                        1.000000                       1.000000
#
#        archiveclient  archiveexpense  archiveotherincome  ...  updatecategory  \
# count  438299.000000   438299.000000       438299.000000  ...   438299.000000
# mean        0.000012        0.000020            0.000015  ...        0.000189
# std         0.001878        0.002168            0.002603  ...        0.005434
# min         0.000000        0.000000            0.000000  ...        0.000000
# 25%         0.000000        0.000000            0.000000  ...        0.000000
# 50%         0.000000        0.000000            0.000000  ...        0.000000
# 75%         0.000000        0.000000            0.000000  ...        0.000000
# max         1.000000        1.000000            1.000000  ...        1.000000
#
#         updateclient  updatecompanyprofile  updatecontractor  \
# count  438299.000000         438299.000000     438299.000000
# mean        0.000329              0.000494          0.000715
# std         0.002922              0.009972          0.012097
# min         0.000000              0.000000          0.000000
# 25%         0.000000              0.000000          0.000000
# 50%         0.000000              0.000000          0.000000
# 75%         0.000000              0.000000          0.000000
# max         1.000000              1.000000          1.000000
#
#        updatecreditnote  updateestimate  updateexpense  updateinvoicesample  \
# count     438299.000000   438299.000000  438299.000000        438299.000000
# mean           0.000008        0.000370       0.000180             0.036865
# std            0.001842        0.006264       0.004341             0.089592
# min            0.000000        0.000000       0.000000             0.000000
# 25%            0.000000        0.000000       0.000000             0.000000
# 50%            0.000000        0.000000       0.000000             0.000000
# 75%            0.000000        0.000000       0.000000             0.000000
# max            1.000000        1.000000       1.000000             1.000000
#
#           updateitem  updateservice
# count  438299.000000  438299.000000
# mean        0.000053       0.000068
# std         0.001851       0.001725
# min         0.000000       0.000000
# 25%         0.000000       0.000000
# 50%         0.000000       0.000000
# 75%         0.000000       0.000000
# max         1.000000       1.000000
#
# [8 rows x 87 columns]

# %% [markdown]
# ## 3. Determine Number of Clusters: BIC Score Method

# %%
############################# Determine the Number of Clusters ########################################
# from sklearn.mixture import GaussianMixture

# gm_bic= []
# gm_score=[]
# for i in range(5,10):
#     gm = GaussianMixture(n_components=i,n_init=10,tol=1e-3,max_iter=1000).fit(df_nosystemid)
#     print("BIC for number of cluster(s) {}: {}".format(i,gm.bic(df_nosystemid)))
#     print("Log-likelihood score for number of cluster(s) {}: {}".format(i,gm.score(df_nosystemid)))
#     print("-"*100)
#     gm_bic.append(-gm.bic(df_nosystemid))
#     gm_score.append(gm.score(df_nosystemid))

# %%
# plt.title("The Gaussian Mixture model BIC \nfor determining number of clusters\n",fontsize=16)
# plt.scatter(x=[i for i in range(5,10)],y=np.log(gm_bic),s=150,edgecolor='k')
# plt.grid(True)
# plt.xlabel("Number of clusters",fontsize=14)
# plt.ylabel("Log of Gaussian mixture BIC score",fontsize=15)
# plt.xticks([i for i in range(2,12)],fontsize=14)
# plt.yticks(fontsize=15)
# plt.show()

# %% [markdown]
# ## 4. Fitting GMM Clustering
# From the above elbow graph, we fix number of clusters n = 6.

# %%
##################################### GMM Training (n=6) #######################################################

# GMM fitting to the data 
from sklearn.mixture import GaussianMixture
gmm = GaussianMixture(n_components=6)
gmm.fit(df_nosystemid)


# Predicting clustering
cluster_predict = gmm.predict(df_nosystemid)

# Adding clusters id of each account to the dataframe
df_orig['cluster_id'] = cluster_predict

# save the model to disk
filename_clustering = '/Users/dwahid/Documents/GitHub/fraud_detection/src/saved_models/fraud_detection_clustering_day_49_k6_model.sav'
pickle.dump(gmm, open(filename_clustering, 'wb'))

# Export the original users data with corresponding cluster id label (clustering output)
df_orig.to_csv("/Users/dwahid/Documents/GitHub/fraud_detection/data/model_outputs_gmm_for_nn_training/gmm_clutering_outputs_day_49_k6.tsv", 
               sep="\t", index=False)

# %%
##################################### GMM Training (n=7) #######################################################

# GMM fitting to the data 
from sklearn.mixture import GaussianMixture
gmm = GaussianMixture(n_components=7)
gmm.fit(df_nosystemid)


# Predicting clustering
cluster_predict = gmm.predict(df_nosystemid)

# Adding clusters id of each account to the dataframe
df_orig['cluster_id'] = cluster_predict

# save the model to disk
filename_clustering = '/Users/dwahid/Documents/GitHub/fraud_detection/src/saved_models/fraud_detection_clustering_day_49_k7_model.sav'
pickle.dump(gmm, open(filename_clustering, 'wb'))

# Export the original users data with corresponding cluster id label (clustering output)
df_orig.to_csv("/Users/dwahid/Documents/GitHub/fraud_detection/data/model_outputs_gmm_for_nn_training/gmm_clutering_outputs_day_49_k7.tsv", 
               sep="\t", index=False)

# %%
##################################### GMM Training (n=8) #######################################################

# GMM fitting to the data 
from sklearn.mixture import GaussianMixture
gmm = GaussianMixture(n_components=8)
gmm.fit(df_nosystemid)


# Predicting clustering
cluster_predict = gmm.predict(df_nosystemid)

# Adding clusters id of each account to the dataframe
df_orig['cluster_id'] = cluster_predict

# save the model to disk
filename_clustering = '/Users/dwahid/Documents/GitHub/fraud_detection/src/saved_models/fraud_detection_clustering_day_49_k8_model.sav'
pickle.dump(gmm, open(filename_clustering, 'wb'))

# Export the original users data with corresponding cluster id label (clustering output)
df_orig.to_csv("/Users/dwahid/Documents/GitHub/fraud_detection/data/model_outputs_gmm_for_nn_training/gmm_clutering_outputs_day_49_k8.tsv", 
               sep="\t", index=False)
